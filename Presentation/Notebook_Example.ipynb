# %%
import glob
pdb_vars = glob.glob("./Data/test_data/*.pdb")
gro_vars = glob.glob("./Data/test_data/*.gro")
mol_vars = glob.glob("./Data/test_data/*.mol")
dd_vars = pdb_vars + gro_vars + mol_vars
for i in range(len(dd_vars)):
    dd_vars[i] = "./Data/test_data/" + dd_vars[i][17:]
print(dd_vars)
# Out:
# ['./Data/test_data/Complex1.pdb', './Data/test_data/Na_W_cluster5.pdb', './Data/test_data/Na_W_cluster7.pdb', './Data/test_data/Na_W_cluster7a.pdb', './Data/test_data/Complex1.gro']
