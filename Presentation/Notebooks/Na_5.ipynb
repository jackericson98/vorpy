# %% [markdown]
# # Vorpy User Example
# ### John Ericson
# ### 06/01/2022
# ### GSU Chemistry Department

# %% [markdown]
# ### Change directory and grab our imports

# %%
import os
os.chdir("../..") # If you end up in the wrong directory restart the kernal

# %%
from System.system import *
from Network.build_network import build_network, connect_network
from Meshes.build_meshes import build_meshes, make_mesh
# %matplotlib notebook
import matplotlib.pyplot as plt
from Presentation.Visualize.visualize import *

# %% [markdown]
# ## Load the system

# %%
m_file = "./Data/test_data/Na_W_cluster7.pdb"
b_file = "./Data/test_data/Na_W_cluster7_balls.txt"
v_file = "./Data/test_data/Na_W_cluster7_vertices.txt"
sys1 = System(m_file)
sys = System(m_file)

# %% [markdown]
# ## Build the network

# %%
build_network(sys1)
sys.add_vta_data(b_file, v_file)
sys = connect_network(sys)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23556/1125217193.py in <module>
#       1 build_network(sys1)
# ----> 2 sys.add_vta_data(b_file, v_file)
#       3 sys = connect_network(sys)
#
# ~\PycharmProjects\vorpy\System\system.py in add_vta_data(self, ball_file, vert_file)
#     171             data = ball_file[i].split(" ")
#     172             # Grab the data reference for the atoms
# --> 173             balls.append(self.atoms[int(data[5])])
#     174         # Interpret the vertices
#     175         for i in range(len(vert_file)):
#
# IndexError: list index out of range

# %% [markdown]
# ## Build the meshes

# %%
#build_meshes(sys, min_dist=0.5)
# build_meshes(sys1, min_dist=0.5)
print("")

# %% [markdown]
# ## Plot the system

# %%
make_mesh(sys1.net.atoms[0].surfs[2], .5)
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
plot_atoms(sys1.net.atoms[0].surfs[2].atoms, fig=fig, ax=ax, alpha=0.1)
plot_verts(sys1.net.atoms[0].surfs[2].verts, fig=fig, ax=ax)
plot_edges(sys1.net.atoms[0].surfs[2].edges, fig=fig, ax=ax)
plot_surfs([sys1.net.atoms[0].surfs[2]], fig=fig, ax=ax, alpha=1, Show=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
