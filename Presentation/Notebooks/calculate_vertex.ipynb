# %% [markdown]
# # Calculate Vertex

# %%
import os
os.chdir("../..")
from System.system import System, Edge, Surface
from Network.build_network import calc_vert, build_network
from Cells.build_mesh import calc_surf, build_meshes
from Presentation.Visualize.visualize import plot_atoms, plot_verts, plot_surfs, plot_edges
import matplotlib.pyplot as plt

# %%
# Create atom objects from sets of points
atoms = [[[2, 0, -1], 5]]
dist = 5
rad = 2

atoms += [[[dist, 0, 2], rad+2], [[0, 0, dist], rad+2], [[0, dist, 0], rad+2]]
sys = System(atoms)

# %%
myVert = calc_vert(sys.atoms)

# %%
# Set up the plot
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(projection="3d")
ax.set_title("Basic Cube Cell")
# Plot the elements of the network
plot_atoms(sys.atoms, fig=fig, ax=ax, dfo=2, alpha=0.1, colors=['w', 'r', 'r', 'r'])
plot_verts([myVert], plot_spheres=True, fig=fig, ax=ax, Show=True)
#plot_edges(sys.net.edges, fig=fig, ax=ax)
# plot_surfs(sys.net.surfs, fig=fig, ax=ax, Show=True, dfo=10)
# Out:
# <img src="data:image/png;base64,..." width="640">
