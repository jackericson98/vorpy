# %% [markdown]
# # Vorpy User Example
# ### John Ericson
# ### 06/01/2022
# ### GSU Chemistry Department

# %% [markdown]
# ### Change directory and grab our imports

# %%
import os
os.chdir("../..") # If you end up in the wrong directory restart the kernal

# %% [markdown]
# ## Import th system object

# %%
from System.system import System
import matplotlib.pyplot as plt
from Visualize.visualize import *

# %% [markdown]
# ## Load the system

# %%
sys = System("./Data/test_data/Na_W_cluster5.pdb")

# %% [markdown]
# ## Build the network

# %%
sys.net.build()
# Out:
# Network Builtork:  #######    74 % #          10 % #          17 % ##         22 % ###        31 % ###        39 % ####       45 % #####      50 % #####      55 % #####      57 % #####      57 % #####      59 % ######     60 % ######     63 % ######     69 % #######    71 % #######    71 % #######    71 % #######    71 % #######    72 % #######    73 % #######    74 % #######    74 %
#
# Building Surfaces:            3 %
# /Users/jackericson/PycharmProjects/vorpy/System/sys_funcs.py:18: RuntimeWarning: invalid value encountered in true_divide
#   n0, n1 = v0/np.linalg.norm(v0), v1/np.linalg.norm(v1)
# Building Surfaces: ########   87 % ####       41 % #######    71 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/c_/0rl3t9752h5dw7f19km74gtm0000gn/T/ipykernel_57826/4196132099.py in <module>
# ----> 1 sys.net.build()
#
# ...

# %% [markdown]
# ## Plot the system

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
plot_atoms(sys.net.atoms[0].surfs[2].atoms, fig=fig, ax=ax, alpha=0.1)
plot_verts(sys.net.atoms[0].surfs[2].verts, fig=fig, ax=ax)
plot_edges(sys.net.atoms[0].surfs[2].edges, fig=fig, ax=ax)
plot_surfs([sys.net.atoms[0].surfs[2]], fig=fig, ax=ax, alpha=1, Show=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
