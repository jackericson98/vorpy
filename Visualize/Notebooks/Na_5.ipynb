# %% [markdown]
# # Vorpy User Example
# ### John Ericson
# ### 06/01/2022
# ### GSU Chemistry Department

# %% [markdown]
# ### Change directory and grab our imports

# %%
import os
os.chdir("../..") # If you end up in the wrong directory restart the kernal

# %% [markdown]
# ## Import th system object

# %%
from System.system import System
import matplotlib.pyplot as plt
from Visualize.mpl_visualize import *

# %% [markdown]
# ## Load the system

# %%
# Get the System
sys = System(os.getcwd() + "/Data/test_data/triplet_doublet1.pdb")

# %% [markdown]
# ## Build the network

# %%
sys.build_network(sol_verts=False, surf_res=0.2, max_vert=5, box_size=1.5)
# Out:
# Analyzing: 100 %

# %% [markdown]
# ## Plot the system

# %%
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(projection="3d")
plot_atoms(sys.atoms[3:6] + sys.atoms[53:54], fig=fig, ax=ax)

plot_verts(sys.net.verts, fig=fig, ax=ax)
plot_edges(sys.net.edges, fig=fig, ax=ax, Show=True)
# Out:
# <img src="data:image/png;base64,..." width="850">

# %% [markdown]
# ## Analyze the system
