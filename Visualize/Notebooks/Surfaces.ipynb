# %% [markdown]
# # Surfaces

# %%
import os
os.chdir("../..")

# %% [markdown]
# ## Get the relevant imports

# %%
from System.system import *
from Visualize.mpl_visualize import *

# %% [markdown]
# ## Set up the different surface cases

# %% [markdown]
# ## Make the surfaces and buld the meshes

# %%
vert_atoms = [Atom([1, 5, 5], 2.5), Atom([1, -5, 5], 2.5), Atom([1, 5, -5], 2.5), Atom([1, -5, -5], 2.5)]


cases = [System(atoms=[Atom([-1, 0, 0], .5), Atom([3, 0, 0], .5)] + vert_atoms), 
         System(atoms=[Atom([-1.5, 0, 0], 1.5), Atom([1, 0, 0], 0.5)] + vert_atoms), 
         System(atoms=[Atom([-1.5, 0, 0], 1.5), Atom([0.5, 0, 0], 0.5)] + vert_atoms), 
         System(atoms=[Atom([-1.5, 0, 0], 1.5), Atom([0.1, 0, 0], 0.5)] + vert_atoms), 
         System(atoms=[Atom([-1.5, 0, 0], 1.5), Atom([0, 0, 0], 0.5)] + vert_atoms), 
         System(atoms=[Atom([-1.5, 0, 0], 1.5), Atom([-0.25, 0, 0], 0.5)] + vert_atoms), 
         System(atoms=[Atom([-1.5, 0, 0], 1.5), Atom([-0.49, 0, 0], 0.5)] + vert_atoms), 
         System(atoms=[Atom([-1.5, 0, 0], 1.5), Atom([-0.5, 0, 0], 0.5)] + vert_atoms), 
         System(atoms=[Atom([-1.5, 0, 0], 1.5), Atom([-0.55, 0, 0], 0.5)] + vert_atoms)]

# %%
# %matplotlib notebook
for sys in cases:
    sys.build_network(0.1)
    if sys.net.surfs is not None:
        fig = plt.figure(figsize=(10, 10))
        ax = fig.add_subplot(projection="3d", xlim=10)
        plot_verts(sys.net.surfs[0].verts, fig=fig, ax=ax)
        plot_atoms(sys.net.surfs[0].atoms, fig=fig, ax=ax, colors=['r', 'b'], alpha=.5)
        plot_edges(sys.net.surfs[0].edges, fig=fig, ax=ax)
        plot_surfs(sys.net.surfs[:1], simps=True, fig=fig, ax=ax, dfo=1.5)
# Out:
# my atoms [<System.atom.Atom object at 0x0000017DF6455460>, <System.atom.Atom object at 0x0000017DF6455100>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  my atoms [<System.atom.Atom object at 0x0000017DF6455460>, <System.atom.Atom object at 0x0000017DF6455100>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . my atoms [<System.atom.Atom object at 0x0000017DF6455460>, <System.atom.Atom object at 0x0000017DF6455100>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . . my atoms [<System.atom.Atom object at 0x0000017DF6455460>, <System.atom.Atom object at 0x0000017DF6455100>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . . . my atoms [<System.atom.Atom object at 0x0000017DF6455460>, <System.atom.Atom object at 0x0000017DF6455100>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  my atoms [<System.atom.Atom object at 0x0000017DF6455460>, <System.atom.Atom object at 0x0000017DF6455100>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . my atoms [<System.atom.Atom object at 0x0000017DF6455460>, <System.atom.Atom object at 0x0000017DF6455100>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Analyzing: 100 %
# <img src="data:image/png;base64,..." width="1000">
# my atoms [<System.atom.Atom object at 0x0000017DF869F370>, <System.atom.Atom object at 0x0000017DF869F340>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  my atoms [<System.atom.Atom object at 0x0000017DF869F370>, <System.atom.Atom object at 0x0000017DF869F340>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . my atoms [<System.atom.Atom object at 0x0000017DF869F370>, <System.atom.Atom object at 0x0000017DF869F340>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . . my atoms [<System.atom.Atom object at 0x0000017DF869F370>, <System.atom.Atom object at 0x0000017DF869F340>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . . . my atoms [<System.atom.Atom object at 0x0000017DF869F370>, <System.atom.Atom object at 0x0000017DF869F340>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  my atoms [<System.atom.Atom object at 0x0000017DF869F370>, <System.atom.Atom object at 0x0000017DF869F340>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . my atoms [<System.atom.Atom object at 0x0000017DF869F370>, <System.atom.Atom object at 0x0000017DF869F340>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Analyzing: 100 % 1/1
# <img src="data:image/png;base64,..." width="1000">
# my atoms [<System.atom.Atom object at 0x0000017DF869F3D0>, <System.atom.Atom object at 0x0000017DF86B7E80>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  my atoms [<System.atom.Atom object at 0x0000017DF869F3D0>, <System.atom.Atom object at 0x0000017DF86B7E80>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . my atoms [<System.atom.Atom object at 0x0000017DF869F3D0>, <System.atom.Atom object at 0x0000017DF86B7E80>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . . my atoms [<System.atom.Atom object at 0x0000017DF869F3D0>, <System.atom.Atom object at 0x0000017DF86B7E80>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . . . my atoms [<System.atom.Atom object at 0x0000017DF869F3D0>, <System.atom.Atom object at 0x0000017DF86B7E80>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  my atoms [<System.atom.Atom object at 0x0000017DF869F3D0>, <System.atom.Atom object at 0x0000017DF86B7E80>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . my atoms [<System.atom.Atom object at 0x0000017DF869F3D0>, <System.atom.Atom object at 0x0000017DF86B7E80>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Analyzing: 100 % 1/1
# <img src="data:image/png;base64,..." width="1000">
# my atoms [<System.atom.Atom object at 0x0000017DF86B7F10>, <System.atom.Atom object at 0x0000017DF86B7F40>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  my atoms [<System.atom.Atom object at 0x0000017DF86B7F10>, <System.atom.Atom object at 0x0000017DF86B7F40>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . my atoms [<System.atom.Atom object at 0x0000017DF86B7F10>, <System.atom.Atom object at 0x0000017DF86B7F40>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . . my atoms [<System.atom.Atom object at 0x0000017DF86B7F10>, <System.atom.Atom object at 0x0000017DF86B7F40>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . . . my atoms [<System.atom.Atom object at 0x0000017DF86B7F10>, <System.atom.Atom object at 0x0000017DF86B7F40>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  my atoms [<System.atom.Atom object at 0x0000017DF86B7F10>, <System.atom.Atom object at 0x0000017DF86B7F40>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . my atoms [<System.atom.Atom object at 0x0000017DF86B7F10>, <System.atom.Atom object at 0x0000017DF86B7F40>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Analyzing: 100 % 1/1
# <img src="data:image/png;base64,..." width="1000">
# my atoms [<System.atom.Atom object at 0x0000017DF86B7FD0>, <System.atom.Atom object at 0x0000017DF86B7A30>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  my atoms [<System.atom.Atom object at 0x0000017DF86B7FD0>, <System.atom.Atom object at 0x0000017DF86B7A30>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . my atoms [<System.atom.Atom object at 0x0000017DF86B7FD0>, <System.atom.Atom object at 0x0000017DF86B7A30>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . . my atoms [<System.atom.Atom object at 0x0000017DF86B7FD0>, <System.atom.Atom object at 0x0000017DF86B7A30>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . . . my atoms [<System.atom.Atom object at 0x0000017DF86B7FD0>, <System.atom.Atom object at 0x0000017DF86B7A30>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  my atoms [<System.atom.Atom object at 0x0000017DF86B7FD0>, <System.atom.Atom object at 0x0000017DF86B7A30>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . my atoms [<System.atom.Atom object at 0x0000017DF86B7FD0>, <System.atom.Atom object at 0x0000017DF86B7A30>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Analyzing: 100 % 1/1
# <img src="data:image/png;base64,..." width="1000">
# my atoms [<System.atom.Atom object at 0x0000017DF78B40D0>, <System.atom.Atom object at 0x0000017DF645EAF0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  my atoms [<System.atom.Atom object at 0x0000017DF78B40D0>, <System.atom.Atom object at 0x0000017DF645EAF0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . my atoms [<System.atom.Atom object at 0x0000017DF78B40D0>, <System.atom.Atom object at 0x0000017DF645EAF0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . . my atoms [<System.atom.Atom object at 0x0000017DF78B40D0>, <System.atom.Atom object at 0x0000017DF645EAF0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . . . my atoms [<System.atom.Atom object at 0x0000017DF78B40D0>, <System.atom.Atom object at 0x0000017DF645EAF0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  my atoms [<System.atom.Atom object at 0x0000017DF78B40D0>, <System.atom.Atom object at 0x0000017DF645EAF0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . my atoms [<System.atom.Atom object at 0x0000017DF78B40D0>, <System.atom.Atom object at 0x0000017DF645EAF0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Analyzing: 100 % 1/1
# <img src="data:image/png;base64,..." width="1000">
# my atoms [<System.atom.Atom object at 0x0000017DF86B78E0>, <System.atom.Atom object at 0x0000017DF86B78B0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  my atoms [<System.atom.Atom object at 0x0000017DF86B78E0>, <System.atom.Atom object at 0x0000017DF86B78B0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . my atoms [<System.atom.Atom object at 0x0000017DF86B78E0>, <System.atom.Atom object at 0x0000017DF86B78B0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . . my atoms [<System.atom.Atom object at 0x0000017DF86B78E0>, <System.atom.Atom object at 0x0000017DF86B78B0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . . . my atoms [<System.atom.Atom object at 0x0000017DF86B78E0>, <System.atom.Atom object at 0x0000017DF86B78B0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  my atoms [<System.atom.Atom object at 0x0000017DF86B78E0>, <System.atom.Atom object at 0x0000017DF86B78B0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . my atoms [<System.atom.Atom object at 0x0000017DF86B78E0>, <System.atom.Atom object at 0x0000017DF86B78B0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
#                                         my atoms [<System.atom.Atom object at 0x0000017DF86B7820>, <System.atom.Atom object at 0x0000017DF86B77F0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  my atoms [<System.atom.Atom object at 0x0000017DF86B7820>, <System.atom.Atom object at 0x0000017DF86B77F0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . my atoms [<System.atom.Atom object at 0x0000017DF86B7820>, <System.atom.Atom object at 0x0000017DF86B77F0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . . my atoms [<System.atom.Atom object at 0x0000017DF86B7820>, <System.atom.Atom object at 0x0000017DF86B77F0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . . . my atoms [<System.atom.Atom object at 0x0000017DF86B7820>, <System.atom.Atom object at 0x0000017DF86B77F0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  my atoms [<System.atom.Atom object at 0x0000017DF86B7820>, <System.atom.Atom object at 0x0000017DF86B77F0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . my atoms [<System.atom.Atom object at 0x0000017DF86B7820>, <System.atom.Atom object at 0x0000017DF86B77F0>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
#                                         my atoms [<System.atom.Atom object at 0x0000017DF86B7760>, <System.atom.Atom object at 0x0000017DF86B7730>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  my atoms [<System.atom.Atom object at 0x0000017DF86B7760>, <System.atom.Atom object at 0x0000017DF86B7730>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . my atoms [<System.atom.Atom object at 0x0000017DF86B7760>, <System.atom.Atom object at 0x0000017DF86B7730>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . . my atoms [<System.atom.Atom object at 0x0000017DF86B7760>, <System.atom.Atom object at 0x0000017DF86B7730>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . . . my atoms [<System.atom.Atom object at 0x0000017DF86B7760>, <System.atom.Atom object at 0x0000017DF86B7730>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  my atoms [<System.atom.Atom object at 0x0000017DF86B7760>, <System.atom.Atom object at 0x0000017DF86B7730>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
# Checking Missing vertices  . my atoms [<System.atom.Atom object at 0x0000017DF86B7760>, <System.atom.Atom object at 0x0000017DF86B7730>, <System.atom.Atom object at 0x0000017DF6446580>, <System.atom.Atom object at 0x0000017DF869FEE0>, <System.atom.Atom object at 0x0000017DF869FF40>, <System.atom.Atom object at 0x0000017DF869F460>]
