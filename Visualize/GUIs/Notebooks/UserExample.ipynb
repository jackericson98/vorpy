# %% [markdown]
# # Create Network Example

# %%
# Import os and move up a directory
import os
os.chdir("..")

# %%
# Import the System object 
from System.system import System

# %%
# Replace the file with your file
my_sys = System(file="EDTA_Mg", )
